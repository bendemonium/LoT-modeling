# %%
from utils import Element, KComplexity, ElementSet, Associations
import cognitive_functions as cf

# %%
a = Element('A1','A','1')
b = Element('A2','A','2')
c = Element('B1','B','1')
d = Element('B2','B','2')

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.iterate(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 18
# {'add': 0, 'append': 2, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 2, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 8, 'setminus': 6, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [Element(object=A2, attribute 1=A, attribute 2=2), Element(object=A1, attribute 1=A, attribute 2=1), Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)]
# Elapsed time: 3.0399998649954796e-05

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.palindrome(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 9
# {'add': 0, 'append': 1, 'check_if_same_type': 1, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 2, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 2, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [Element(object=B1, attribute 1=B, attribute 2=1), Element(object=A1, attribute 1=A, attribute 2=1)]
# Elapsed time: 7.37000082153827e-05

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.alternate(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 16
# {'add': 0, 'append': 0, 'check_if_same_type': 3, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 4, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2), Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)]
# Elapsed time: 5.4000120144337416e-06

# %%
element_set = {a,b,c,d}
assoc = Associations({a: b, c: d})
S = ElementSet(element_set, assoc)
kc = KComplexity()

result, elapsed_time = cf.chaining(S, assoc)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 15
# {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 0, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 6, 'remove': 0, 'remove_item': 0, 'sample': 5, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [[Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)], [Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2)]]
# Elapsed time: 3.7699996028095484e-05

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
cf.seriate(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 0
# {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 0, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 0, 'setminus': 0, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [[Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)], [Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2)]]
# Elapsed time: 3.7699996028095484e-05

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.serial_crossed(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 28
# {'add': 0, 'append': 0, 'check_if_same_type': 11, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 2, 'remove': 0, 'remove_item': 0, 'sample': 12, 'setminus': 2, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [Element(object=B2, attribute 1=B, attribute 2=2), Element(object=A2, attribute 1=A, attribute 2=2)]
# Elapsed time: 6.799993570894003e-06

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.center_embedded(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 8
# {'add': 0, 'append': 0, 'check_if_same_type': 1, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 2, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 2, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: [Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2)]
# Elapsed time: 7.399969035759568e-06

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.tail_recursive(S)
print(kc.get_k_complexity())
print(kc.get_prim_counts())
print("Result:", result)
print("Elapsed time:", elapsed_time)
# Out:
# 9
# {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 4, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# Result: []
# Elapsed time: 9.6399977337569e-05

# %%
S.visualize()
