# %%
from utils import Element, KComplexity, ElementSet, Associations
import cognitive_functions as cf

# %%
a = Element('A1','A','1')
b = Element('A2','A','2')
c = Element('B1','B','1')
d = Element('B2','B','2')

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
cf.iterate(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
cf.palindrome(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
cf.alternate(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
assoc = Associations({a: b, c: d})
cf.chaining(S, assoc)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
cf.seriate(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
cf.serial_crossed(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
cf.center_embedded(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

element_set = {a,b,c,d}
S = ElementSet(element_set)
cf.tail_recursive(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()

print('Total K-complexity: ', kc.get_total_k_complexity())
print('Total primitive counts: ', kc.get_total_prim_counts())
kc.plot_total_prim_counts()
kc.plot_cog_vs_prim()
# Out:
# iterate k-complexity:  18
# iterate primitive count:  {'add': 0, 'append': 2, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 2, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 8, 'setminus': 6, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# palindrome k-complexity:  11
# palindrome primitive count:  {'add': 0, 'append': 1, 'check_if_same_type': 2, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 2, 'remove': 0, 'remove_item': 0, 'sample': 3, 'setminus': 2, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# alternate k-complexity:  18
# alternate primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 4, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 5, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# chaining k-complexity:  15
# chaining primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 0, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 6, 'remove': 0, 'remove_item': 0, 'sample': 5, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# seriate k-complexity:  0
# seriate primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 0, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 0, 'setminus': 0, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}
# serial_crossed k-complexity:  16
# serial_crossed primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 2, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 3, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}
# center_embedded k-complexity:  20
# center_embedded primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 4, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 5, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}
# tail_recursive k-complexity:  13
# tail_recursive primitive count:  {'add': 0, 'append': 2, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 2, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}
# Total K-complexity:  111
# Total primitive counts:  {'add': 0, 'append': 5, 'check_if_same_type': 12, 'dim_set': 0, 'flip': 7, 'implement': 0, 'list_create': 0, 'merge': 2, 'pair': 20, 'remove': 0, 'remove_item': 0, 'sample': 31, 'setminus': 28, 'write_all': 0, 'write_all_set': 0, 'write_random': 6}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.iterate(S)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2), Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)]
# Elapsed time: 0.0018539996817708015
# iterate k-complexity:  18
# iterate primitive count:  {'add': 0, 'append': 2, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 2, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 8, 'setminus': 6, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.palindrome(S)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)]
# Elapsed time: 0.0015916000120341778
# palindrome k-complexity:  9
# palindrome primitive count:  {'add': 0, 'append': 1, 'check_if_same_type': 1, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 2, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 2, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.alternate(S)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2), Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2)]
# Elapsed time: 0.0003559999167919159
# alternate k-complexity:  22
# alternate primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 6, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 7, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
assoc = Associations({a: b, c: d})
kc = KComplexity()
result, elapsed_time = cf.chaining(S, assoc)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [[Element(object=A1, attribute 1=A, attribute 2=1), Element(object=A2, attribute 1=A, attribute 2=2)], [Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2)]]
# Elapsed time: 0.0021164000499993563
# chaining k-complexity:  20
# chaining primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 0, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 6, 'remove': 0, 'remove_item': 0, 'sample': 10, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
cf.seriate(S)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# seriate k-complexity:  0
# seriate primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 0, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 0, 'setminus': 0, 'write_all': 0, 'write_all_set': 0, 'write_random': 0}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.serial_crossed(S)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [Element(object=B2, attribute 1=B, attribute 2=2), Element(object=A2, attribute 1=A, attribute 2=2), Element(object=B1, attribute 1=B, attribute 2=1), Element(object=A1, attribute 1=A, attribute 2=1)]
# Elapsed time: 0.0004013997968286276
# serial_crossed k-complexity:  14
# serial_crossed primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 1, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.center_embedded(S)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [Element(object=A1, attribute 1=A, attribute 2=1), Element(object=B1, attribute 1=B, attribute 2=1), Element(object=B2, attribute 1=B, attribute 2=2), Element(object=A2, attribute 1=A, attribute 2=2)]
# Elapsed time: 0.0003448999486863613
# center_embedded k-complexity:  14
# center_embedded primitive count:  {'add': 0, 'append': 0, 'check_if_same_type': 1, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 0, 'pair': 4, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}

# %%
element_set = {a,b,c,d}
S = ElementSet(element_set)
kc = KComplexity()
result, elapsed_time = cf.tail_recursive(S)
print("Result:", result)
print("Elapsed time:", elapsed_time)
print(kc.get_cog_name() + ' k-complexity: ', kc.get_k_complexity())
print(kc.get_cog_name() + ' primitive count: ', kc.get_prim_counts())
kc.plot_prim_counts()
# Out:
# Result: [Element(object=A2, attribute 1=A, attribute 2=2), Element(object=B2, attribute 1=B, attribute 2=2), Element(object=A1, attribute 1=A, attribute 2=1), Element(object=B1, attribute 1=B, attribute 2=1)]
# Elapsed time: 0.0029325999785214663
# tail_recursive k-complexity:  13
# tail_recursive primitive count:  {'add': 0, 'append': 2, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 2, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}

# %%
S.visualize()
print('Total K-complexity: ', kc.get_total_k_complexity())
print('Total primitive counts: ', kc.get_total_prim_counts())
kc.plot_total_prim_counts()
kc.plot_cog_vs_prim()
# Out:
# Total K-complexity:  13
# Total primitive counts:  {'add': 0, 'append': 2, 'check_if_same_type': 0, 'dim_set': 0, 'flip': 1, 'implement': 0, 'list_create': 0, 'merge': 2, 'pair': 0, 'remove': 0, 'remove_item': 0, 'sample': 2, 'setminus': 4, 'write_all': 0, 'write_all_set': 0, 'write_random': 2}
